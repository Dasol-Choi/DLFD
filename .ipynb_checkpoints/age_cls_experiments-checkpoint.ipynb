# %% [markdown]
# ### Download Dataset

# %%
# %%capture
# !wget https://postechackr-my.sharepoint.com/:u:/g/personal/dongbinna_postech_ac_kr/EbMhBPnmIb5MutZvGicPKggBWKm5hLs0iwKfGW7_TwQIKg?download=1 -O custom_korean_family_dataset_resolution_128.zip
# !unzip custom_korean_family_dataset_resolution_128.zip -d ./custom_korean_family_dataset_resolution_128

# %%
import os
import time
import random
import glob
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms, models
import torchvision.transforms.functional as TF
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import CosineAnnealingLR
from trainer import train, test
from evaluation.mia import MIA
from evaluation.accuracy import calculate_accuracy, calculate_all_accuracies
from model import load_model
from MUFAC_loader import get_data_loaders
import warnings
warnings.filterwarnings("ignore")

# %%
# Define paths
train_meta_data_path = "custom_korean_family_dataset_resolution_128/custom_train_dataset.csv"
train_image_directory = "custom_korean_family_dataset_resolution_128/train_images"

val_meta_data_path = "custom_korean_family_dataset_resolution_128/custom_val_dataset.csv"
val_image_directory = "custom_korean_family_dataset_resolution_128/val_images"

test_meta_data_path = "custom_korean_family_dataset_resolution_128/custom_test_dataset.csv"
test_image_directory = "custom_korean_family_dataset_resolution_128/test_images"

batch_size = 32
data_loaders = get_data_loaders(
    train_meta_data_path, train_image_directory,
    val_meta_data_path, val_image_directory,
    test_meta_data_path, test_image_directory, batch_size
)

print(f"Number of training samples: {len(data_loaders['train'].dataset)}")
print(f"Number of test samples: {len(data_loaders['test'] .dataset)}")
print(f"Number of val samples: {len(data_loaders['val'].dataset)}")
print(f"Number of retained train samples: {len(data_loaders['retain_train'].dataset)}")
print(f"Number of forgotten train samples: {len(data_loaders['forget_train'].dataset)}")
# Out:
# Number of training samples: 10025
# Number of test samples: 1504
# Number of val samples: 1539
# Number of retained train samples: 8525
# Number of forgotten train samples: 1500

# %% [markdown]
# ## Base Model

# %% [markdown]
# ### Training Original Model

# %%
learning_rate = 0.01
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = load_model(8, device, model_path=None)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)
scheduler = CosineAnnealingLR(optimizer, T_max=200)

num_epochs = 100
best_val_acc = 0
best_epoch = 0

history = []
accuracy = []
for epoch in range(num_epochs):
    train_loss, train_acc = train(model, data_loaders['train'], criterion, optimizer, scheduler, device, epoch)
    val_loss, val_acc = test(model, data_loaders['val'], criterion, device)
    history.append((train_loss, train_acc))
    accuracy.append((val_loss, val_acc))

    if val_acc > best_val_acc:
        print("[Info] best test accuracy!")
        best_val_acc = val_acc
        best_epoch = epoch
        #torch.save(model.state_dict(), f'checkpoints/resnet/best_{epoch + 1}_age_original.pth')

#torch.save(model.state_dict(), f'checkpoints/resnet/last_{num_epochs}_age_original.pth')

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_path =  'checkpoint/last_100_age_original.pth'
model = load_model(8, device, model_path)
criterion = nn.CrossEntropyLoss()

test_acc = calculate_accuracy(model, data_loaders['test'], criterion, device)
mia = MIA(model, data_loaders["retain_test"], data_loaders['forget_test'], data_loaders['test'], device)
final_score = (test_acc["Acc"] + 1 - abs(mia["Forgetting Score"] * 2)) / 2
print(f'Test Acc: {test_acc}')
print(f'MIA: {mia}')
print(f'Final score: {final_score}')
# Out:
# Test Acc: {'Loss': 0.0374256043516575, 'Acc': 0.6329787234042553, 'Top-2 Acc': 0.8803191489361702}
# MIA: {'MIA Regression Accuracy': 0.7618180241131061, 'MIA CV Accuracy': 0.6923588039867109, 'Forgetting Score': 0.1923588039867109}
# Final score: 0.6241305577154167

# %% [markdown]
# ### Training Retrained Model

# %%
learning_rate = 0.01
retrained_model = load_model(8, device, model_path=None)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(retrained_model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)
scheduler = CosineAnnealingLR(optimizer, T_max=200)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

num_epochs = 100
best_val_acc = 0
best_epoch = 0

history = []
accuracy = []
for epoch in range(num_epochs):
    train_loss, train_acc = train(retrained_model, data_loaders['retain_train'], criterion, optimizer, scheduler, device, epoch)
    val_loss, val_acc = test(retrained_model, data_loaders['val'], criterion, device)
    history.append((train_loss, train_acc))
    accuracy.append((val_loss, val_acc))

    if val_acc > best_val_acc:
        print("[Info] best test accuracy!")
        best_val_acc = val_acc
        best_epoch = epoch
        #torch.save(retrained_model.state_dict(), f'checkpoint/best_{epoch + 1}_age_retrained.pth')

#torch.save(retrained_model.state_dict(), f'checkpoint/last_{num_epochs}_age_retrained.pth')

# %%
model_path = 'checkpoint/last_100_age_retrained.pth'
retrained_model = load_model(8, device, model_path)
criterion = nn.CrossEntropyLoss()

test_acc = calculate_accuracy(retrained_model, data_loaders['test'], criterion, device)
mia = MIA(retrained_model, data_loaders["retain_test"], data_loaders['forget_test'], data_loaders['test'], device)
final_score = (test_acc["Acc"] + 1 - abs(mia["Forgetting Score"] * 2)) / 2
print(f'Test Acc: {test_acc}')
print(f'MIA: {mia}')
print(f'Final score: {final_score}')
# Out:
# Test Acc: {'Loss': 0.037642640834476084, 'Acc': 0.6083776595744681, 'Top-2 Acc': 0.8656914893617021}
# MIA: {'MIA Regression Accuracy': 0.7678896695290138, 'MIA CV Accuracy': 0.5548172757475083, 'Forgetting Score': 0.054817275747508276}
# Final score: 0.7493715540397258

# %% [markdown]
# ## Unlearning Experiments

# %% [markdown]
# ### Fine-tunning

# %%
model_path =  'checkpoint/last_100_age_original.pth'
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
finetune_model = load_model(8, device, model_path)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(finetune_model.parameters(), lr=0.001, momentum=0.9, weight_decay=5e-4)
num_epochs=2
scheduler = CosineAnnealingLR(optimizer, T_max=num_epochs)
for epoch in range(num_epochs):
    train_loss, train_acc = train(finetune_model, data_loaders['retain_train'], criterion, optimizer, scheduler, device, epoch)
    val_loss, val_acc = test(finetune_model, data_loaders['val'], criterion, device)

test_acc = calculate_accuracy(finetune_model, data_loaders['test'], criterion, device)
mia = MIA(finetune_model, data_loaders["retain_test"], data_loaders['forget_test'], data_loaders['test'], device)
final_score = (test_acc["Acc"] + 1 - abs(mia["Forgetting Score"] * 2)) / 2
print(f'Test Acc: {test_acc}')
print(f'MIA: {mia}')
print(f'Final score: {final_score}')
# Out:
# [Epoch: 1 - Training]
# [Batch: 80] running train loss: 0.010473815829027445, running train accuracy: 0.888671875
# [Batch: 160] running train loss: 0.00998851096665021, running train accuracy: 0.8935546875
# [Batch: 240] running train loss: 0.009844225030974485, running train accuracy: 0.89348965883255
# train loss: 0.009800257664446957, accuracy: 0.8932551145553589
# elapsed time: 15.528449296951294
# [Test]
# [Batch: 1] running test loss: 0.0499936044216156, running test accuracy: 0.59375
# test loss: 0.045445403005489673, accuracy: 0.5724496245384216
# elapsed time: 1.0893614292144775
# [Epoch: 2 - Training]
# [Batch: 80] running train loss: 0.008728485857136547, running train accuracy: 0.903124988079071
# [Batch: 160] running train loss: 0.008625717423274181, running train accuracy: 0.8994140625
# [Batch: 240] running train loss: 0.008521037284905712, running train accuracy: 0.9027343988418579
# train loss: 0.008530318191673748, accuracy: 0.9031084775924683
# elapsed time: 15.045075178146362
# [Test]
# [Batch: 1] running test loss: 0.04759373143315315, running test accuracy: 0.625
# test loss: 0.047057011051562174, accuracy: 0.5646523833274841
# elapsed time: 1.0029397010803223
# Test Acc: {'Loss': 0.0396959254557782, 'Acc': 0.6376329787234043, 'Top-2 Acc': 0.8969414893617021}
# MIA: {'MIA Regression Accuracy': 0.7671090294041114, 'MIA CV Accuracy': 0.6883720930232557, 'Forgetting Score': 0.18837209302325575}
# Final score: 0.6304443963384464

# %% [markdown]
# ### CF-K

# %%
from unlearn.cfk import cfk_train

model_path =  'checkpoint/last_100_age_original.pth'
device = torch.device("cuda:0" if torch.cuda.is_available() else "CPU")
criterion = nn.CrossEntropyLoss()
epochs=2
cfk_model = load_model(8, device, model_path)
cfk_model = cfk_train(cfk_model, data_loaders['retain_train'], data_loaders['test'], device, epochs)

test_acc = calculate_accuracy(cfk_model, data_loaders['test'], criterion, device)
mia = MIA(cfk_model, data_loaders["retain_test"], data_loaders['forget_test'], data_loaders['test'], device)
final_score = (test_acc["Acc"] + 1 - abs(mia["Forgetting Score"] * 2)) / 2
print(f'Test Acc: {test_acc}')
print(f'MIA: {mia}')
print(f'Final score: {final_score}')
# Out:
# [Epoch: 1 - Training]
# [Batch: 80] running train loss: 0.011000621796119959, running train accuracy: 0.876171886920929
# [Batch: 160] running train loss: 0.010439964865508956, running train accuracy: 0.885937511920929
# [Batch: 240] running train loss: 0.010353822650116248, running train accuracy: 0.8878906965255737
# train loss: 0.010294202425437939, accuracy: 0.8877419233322144
# elapsed time: 11.836766481399536
# [Test]
# [Batch: 1] running test loss: 0.03943987563252449, running test accuracy: 0.59375
# test loss: 0.037975033626277396, accuracy: 0.6309840083122253
# elapsed time: 0.9689269065856934
# Epoch [1/2] - Train Loss: 0.0103, Train Accuracy: 0.89%
# Epoch [1/2] - Test Loss: 0.0380, Test Accuracy: 0.63%
# [Epoch: 2 - Training]
# [Batch: 80] running train loss: 0.009430807890021242, running train accuracy: 0.8960937857627869
# [Batch: 160] running train loss: 0.010034417739370837, running train accuracy: 0.891406238079071
# [Batch: 240] running train loss: 0.01028650209773332, running train accuracy: 0.8854166865348816
# train loss: 0.010275076113837905, accuracy: 0.8863343000411987
# elapsed time: 11.48568844795227
# [Test]
# [Batch: 1] running test loss: 0.039746325463056564, running test accuracy: 0.59375
# test loss: 0.03860155772417784, accuracy: 0.6223403811454773
# elapsed time: 0.9659271240234375
# Epoch [2/2] - Train Loss: 0.0103, Train Accuracy: 0.89%
# Epoch [2/2] - Test Loss: 0.0386, Test Accuracy: 0.62%
# Test Acc: {'Loss': 0.03860155772417784, 'Acc': 0.6223404255319149, 'Top-2 Acc': 0.879654255319149}
# MIA: {'MIA Regression Accuracy': 0.7617312863214503, 'MIA CV Accuracy': 0.683720930232558, 'Forgetting Score': 0.18372093023255798}
# Final score: 0.6274492825333995

# %% [markdown]
# ### EU-K

# %%
from unlearn.euk import euk_unlearn

epochs = 2
model_path =  'checkpoint/last_100_age_original.pth'
euk_model = load_model(8, device, model_path)
euk_model = euk_unlearn(euk_model, data_loaders['retain_train'], device, epochs)

test_acc = calculate_accuracy(euk_model, data_loaders['test'], criterion, device)
mia = MIA(euk_model, data_loaders["retain_test"], data_loaders['forget_test'], data_loaders['test'], device)
final_score = (test_acc["Acc"] + 1 - abs(mia["Forgetting Score"] * 2)) / 2
print(f'Test Acc: {test_acc}')
print(f'MIA: {mia}')
print(f'Final score: {final_score}')
# Out:
# Unlearning Epoch [1/2] - Loss: 0.3320, Accuracy: 88.47%
# Unlearning Epoch [2/2] - Loss: 0.3204, Accuracy: 89.04%
# Test Acc: {'Loss': 0.03736931507654013, 'Acc': 0.629654255319149, 'Top-2 Acc': 0.8776595744680851}
# MIA: {'MIA Regression Accuracy': 0.7611241217798594, 'MIA CV Accuracy': 0.6893687707641196, 'Forgetting Score': 0.18936877076411962}
# Final score: 0.6254583568954548

# %% [markdown]
# ### NegGrad

# %%
from unlearn.neg_grad import neggrad_unlearn

class Args:
    def __init__(self):
        self.gpu = 0
        self.lr = 0.001
        self.momentum = 0.9
        self.weight_decay = 5e-4
        self.num_classes = 8
        self.epochs = 1
        self.device = torch.device(f"cuda:{self.gpu}" if torch.cuda.is_available() else "cpu")

args = Args()
criterion = nn.CrossEntropyLoss()
model_path =  'checkpoint/last_100_age_original.pth'
neggrad_model = load_model(8, args.device, model_path)
neggrad_unlearn(neggrad_model, data_loaders['forget_train'], criterion, args)

test_acc = calculate_accuracy(neggrad_model, data_loaders['test'], criterion, args.device)
mia = MIA(neggrad_model, data_loaders["retain_test"], data_loaders['forget_test'], data_loaders['test'], args.device)
final_score = (test_acc["Acc"] + 1 - abs(mia["Forgetting Score"] * 2)) / 2
print(f'Test Acc: {test_acc}')
print(f'MIA: {mia}')
print(f'Final score: {final_score}')
# Out:
# NegGrad Epoch [1/1] Loss: 0.846
# Test Acc: {'Loss': 0.11845020474271571, 'Acc': 0.4115691489361702, 'Top-2 Acc': 0.7054521276595744}
# MIA: {'MIA Regression Accuracy': 0.7394396738659034, 'MIA CV Accuracy': 0.4750830564784054, 'Forgetting Score': 0.024916943521594626}
# Final score: 0.6808676309464905

# %% [markdown]
# ### UNSIR

# %%
from unlearn.unsir import Noise, generate_error_maximizing_noise, impair_step, repair_step
from torch.utils.data import DataLoader

class Args:
    def __init__(self):
        self.alpha = 0.1
        self.num_classes = 8
        self.device = torch.device(f"cuda:0" if torch.cuda.is_available() else "cpu")
        self.impair_epochs = 1
        self.repair_epochs = 2
        self.lr = 0.001

args = Args()
criterion = nn.CrossEntropyLoss()
model_path = 'checkpoint/last_100_age_original.pth'
unsir_model = load_model(8, device, model_path)

noise = generate_error_maximizing_noise(unsir_model, data_loaders['forget_train'], args.device, args.impair_epochs)

# Impair Step
noisy_data = [(noise()[i % noise().size(0)], data_loaders['forget_train'].dataset[i][1]) for i in range(len(data_loaders['forget_train'].dataset))]
noisy_loader = DataLoader(noisy_data, batch_size=128, shuffle=True)
impair_step(unsir_model, noisy_loader, args.device, args.lr, args.impair_epochs)

print("Performance of Impaired Model on Forget Samples")
test_acc = calculate_accuracy(unsir_model, data_loaders['test'], criterion, args.device)
mia_impaired = MIA(unsir_model, data_loaders["retain_test"], data_loaders['forget_test'], data_loaders['test'], args.device)
print(f'Test Acc: {test_acc}')
print(f'Impaired MIA : {mia_impaired}')

# Repair Step
repair_step(unsir_model, data_loaders['retain_train'], args.device, args.lr, args.repair_epochs)

print("Performance of Repaired Model on Forget Samples")
test_acc = calculate_accuracy(unsir_model, data_loaders['test'], criterion, args.device)
mia_repaired = MIA(unsir_model, data_loaders["retain_test"], data_loaders['forget_test'], data_loaders['test'], args.device)
final_score = (test_acc["Acc"] + 1 - abs(mia_repaired["Forgetting Score"] * 2)) / 2
print(f'Test Acc: {test_acc}')
print(f'Repaired MIA: {mia_repaired}')
print(f'Final score: {final_score}')
# Out:
# Epoch [1/1] - Noise Loss: 2923.9854
# Impair Step - Train loss 1: 2.9501, Train Acc: 15.40%
# Performance of Impaired Model on Forget Samples
# Test Acc: {'Loss': 0.07558805432091369, 'Acc': 0.2646276595744681, 'Top-2 Acc': 0.3151595744680851}
# Impaired MIA : {'MIA Regression Accuracy': 0.7394396738659034, 'MIA CV Accuracy': 0.5255813953488372, 'Forgetting Score': 0.025581395348837188}
# Repair Step - Train loss 1: 1.2748, Train Acc: 47.91%
# Repair Step - Train loss 2: 2.4218, Train Acc: 100.87%
# Performance of Repaired Model on Forget Samples
# Test Acc: {'Loss': 0.042461668478047596, 'Acc': 0.49069148936170215, 'Top-2 Acc': 0.726063829787234}
# Repaired MIA: {'MIA Regression Accuracy': 0.739613149449215, 'MIA CV Accuracy': 0.5308970099667774, 'Forgetting Score': 0.030897009966777356}
# Final score: 0.7144487347140738

# %% [markdown]
# ### BadT

# %%
from unlearn.badT import badt

class Args:
    def __init__(self):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.seed = 42
        self.bt_optim = "adam"
        self.bt_alpha = 1
        self.bt_beta = 1
        self.bt_kd_T = 4
        self.bt_epochs = 2
        self.bt_learning_rate = 0.001
        self.bt_lr_decay_epochs = [10, 10, 10]
        self.bt_lr_decay_rate = 0.1
        self.bt_weight_decay = 5e-4
        self.bt_momentum = 0.9

args = Args()
criterion = nn.CrossEntropyLoss()
model_path = 'checkpoint/last_100_age_original.pth'
gteacher = load_model(8, args.device, model_path)
bteacher = load_model(8, args.device, model_path=None)
student = load_model(8, args.device, model_path)

badT_model = badt(
    gteacher=gteacher,
    bteacher=bteacher,
    student=student,
    retain_loader=data_loaders["retain_train"],
    forget_loader=data_loaders["forget_train"],
    valid_loader_full=data_loaders["test"],
    args=args
)

test_acc = calculate_accuracy(badT_model, data_loaders['test'], criterion, args.device)
mia = MIA(badT_model, data_loaders["retain_test"], data_loaders['forget_test'], data_loaders['test'], args.device)
final_score = (test_acc["Acc"] + 1 - abs(mia["Forgetting Score"] * 2)) / 2
print(f'Test Acc: {test_acc}')
print(f'MIA: {mia}')
print(f'Final score: {final_score}')
# Out:
# ==> Bad Teacher Unlearning ...
# Epoch 1: train_acc: 35.79, train_loss: -675800.37
# Epoch 2: train_acc: 30.71, train_loss: -27270869.84
# Test Acc: {'Loss': 20565.733281237015, 'Acc': 0.42021276595744683, 'Top-2 Acc': 0.6941489361702128}
# MIA: {'MIA Regression Accuracy': 0.7394396738659034, 'MIA CV Accuracy': 0.5627906976744186, 'Forgetting Score': 0.06279069767441858}
# Final score: 0.6473156853043048

# %% [markdown]
# ### SCRUB

# %%
import torch
from unlearn.scrub import scrub

class Args:
    def __init__(self):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.seed = 42
        self.optim = "sgd"  
        self.sgda_epochs = 2
        self.sgda_learning_rate = 0.0005
        self.sgda_weight_decay = 5e-4
        self.sgda_momentum = 0.9
        self.msteps = 2
        self.kd_T = 4  
        self.lr_decay_epochs = [3, 5, 9]
        self.lr_decay_rate = 0.1

args = Args()
model_path =  'checkpoint/last_100_age_original.pth'
teacher_model = load_model(8, args.device, model_path)
student_model = load_model(8, args.device, model_path)

scrub_model = scrub(
    teacher=teacher_model,
    student=student_model,
    args=args,
    retain_loader_train=data_loaders["retain_train"],
    retain_loader_test=data_loaders["retain_test"],
    forget_loader_train=data_loaders["forget_train"],
    forget_loader_test=data_loaders["forget_test"],
    valid_loader_full=data_loaders["test"] 
)

test_acc = calculate_accuracy(scrub_model, data_loaders['test'], criterion, args.device)
mia = MIA(scrub_model, data_loaders["retain_test"], data_loaders['forget_test'], data_loaders['test'], args.device)
final_score = (test_acc["Acc"] + 1 - abs(mia["Forgetting Score"] * 2)) / 2
print(f'Test Acc: {test_acc}')
print(f'MIA: {mia}')
print(f'Final score: {final_score}')
# Out:
# ==> scrub unlearning ...
# Epoch 1: maximize loss: -3.10, train_acc: 81.24, minimize loss: 1.67
# ==> scrub unlearning ...
# Epoch 2: maximize loss: -2.71, train_acc: 82.97, minimize loss: 1.35
# Total time: 55.80 seconds
# Test Acc: {'Loss': 0.03583506833603407, 'Acc': 0.6462765957446809, 'Top-2 Acc': 0.8769946808510638}
# MIA: {'MIA Regression Accuracy': 0.7619047619047619, 'MIA CV Accuracy': 0.6637873754152824, 'Forgetting Score': 0.16378737541528243}
# Final score: 0.6593509224570581

# %% [markdown]
# ### DLFD

# %%
from unlearn.dlfd import train_dlfd, set_seed, linear_weight_scheduler
set_seed(42) 

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_path = 'checkpoint/last_100_age_original.pth'
dlfm_model = load_model(8, device, model_path)
path = 'checkpoint/age_dlfd.pth'

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(dlfm_model.parameters(), lr=0.008, momentum=0.9, weight_decay=5e-4)

forget_weight = 3.0  # Weight for forgetting
initial_retain_weight = 0  # Initial weight for retaining
final_retain_weight = 1  # Final weight for retaining
perturbation_steps = 15  # Number of steps for perturbation
perturbation_strength = 0.4  # Strength of perturbation
forget_threshold = 0.15  # Forgetting score threshold
best_test_acc = 0  # Save the best test accuracy
max_forgetting_score = 0.09  # Forgetting score saving threshold
val_sample = 300 # Number of samples to use for the monitoring process

train_dlfd(
        dlfm_model, data_loaders, criterion, optimizer, device,
        perturbation_steps, perturbation_strength, forget_threshold, max_forgetting_score,
        initial_retain_weight, final_retain_weight, forget_weight, val_sample, path
    )
# Out:
# Starting Forgetting Phase...
# Batch 1/267 - Test Acc: 0.5445, MIA Forgetting Score: 0.2067, Final Score: 0.5656
# Batch 2/267 - Test Acc: 0.5380, MIA Forgetting Score: 0.1917, Final Score: 0.5773
# Batch 3/267 - Test Acc: 0.5198, MIA Forgetting Score: 0.1883, Final Score: 0.5716
# Batch 4/267 - Test Acc: 0.5166, MIA Forgetting Score: 0.2133, Final Score: 0.5450
# Batch 5/267 - Test Acc: 0.4997, MIA Forgetting Score: 0.2317, Final Score: 0.5182
# Batch 6/267 - Test Acc: 0.4860, MIA Forgetting Score: 0.1967, Final Score: 0.5463
# Batch 7/267 - Test Acc: 0.4691, MIA Forgetting Score: 0.1917, Final Score: 0.5429
# Batch 8/267 - Test Acc: 0.4581, MIA Forgetting Score: 0.1850, Final Score: 0.5440
# Batch 9/267 - Test Acc: 0.4425, MIA Forgetting Score: 0.2083, Final Score: 0.5129
# Batch 10/267 - Test Acc: 0.4256, MIA Forgetting Score: 0.1700, Final Score: 0.5428
# Batch 11/267 - Test Acc: 0.4029, MIA Forgetting Score: 0.1900, Final Score: 0.5114
# Batch 12/267 - Test Acc: 0.3704, MIA Forgetting Score: 0.1950, Final Score: 0.4902
# Batch 13/267 - Test Acc: 0.3502, MIA Forgetting Score: 0.2133, Final Score: 0.4618
# Batch 14/267 - Test Acc: 0.3392, MIA Forgetting Score: 0.2183, Final Score: 0.4513
# Batch 15/267 - Test Acc: 0.3223, MIA Forgetting Score: 0.2083, Final Score: 0.4528
# Batch 16/267 - Test Acc: 0.3034, MIA Forgetting Score: 0.1767, Final Score: 0.4751
# Batch 17/267 - Test Acc: 0.2976, MIA Forgetting Score: 0.1600, Final Score: 0.4888
# Batch 18/267 - Test Acc: 0.2865, MIA Forgetting Score: 0.1750, Final Score: 0.4683
# Batch 19/267 - Test Acc: 0.2775, MIA Forgetting Score: 0.1917, Final Score: 0.4471
# Batch 20/267 - Test Acc: 0.2645, MIA Forgetting Score: 0.1867, Final Score: 0.4456
# Batch 21/267 - Test Acc: 0.2502, MIA Forgetting Score: 0.1933, Final Score: 0.4317
# Batch 22/267 - Test Acc: 0.2450, MIA Forgetting Score: 0.1633, Final Score: 0.4591
# Batch 23/267 - Test Acc: 0.2365, MIA Forgetting Score: 0.1783, Final Score: 0.4399
# Batch 24/267 - Test Acc: 0.2242, MIA Forgetting Score: 0.2167, Final Score: 0.3954
# Batch 25/267 - Test Acc: 0.2209, MIA Forgetting Score: 0.1617, Final Score: 0.4488
# Batch 26/267 - Test Acc: 0.2190, MIA Forgetting Score: 0.1567, Final Score: 0.4528
# Batch 27/267 - Test Acc: 0.2164, MIA Forgetting Score: 0.1517, Final Score: 0.4565
# Batch 28/267 - Test Acc: 0.2105, MIA Forgetting Score: 0.1417, Final Score: 0.4636
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 29/267 - Test Acc: 0.4444, MIA Forgetting Score: 0.0083, Final Score: 0.7139
# New best model saved with Test Acc: 0.4444
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 30/267 - Test Acc: 0.4698, MIA Forgetting Score: 0.0417, Final Score: 0.6932
# New best model saved with Test Acc: 0.4698
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 31/267 - Test Acc: 0.1995, MIA Forgetting Score: 0.0417, Final Score: 0.5581
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 32/267 - Test Acc: 0.2995, MIA Forgetting Score: 0.0433, Final Score: 0.6064
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 33/267 - Test Acc: 0.3132, MIA Forgetting Score: 0.0633, Final Score: 0.5933
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 34/267 - Test Acc: 0.0026, MIA Forgetting Score: 0.0567, Final Score: 0.4446
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 35/267 - Test Acc: 0.1761, MIA Forgetting Score: 0.0183, Final Score: 0.5697
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 36/267 - Test Acc: 0.1605, MIA Forgetting Score: 0.0350, Final Score: 0.5452
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 37/267 - Test Acc: 0.2385, MIA Forgetting Score: 0.0717, Final Score: 0.5476
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 38/267 - Test Acc: 0.2385, MIA Forgetting Score: 0.0250, Final Score: 0.5942
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 39/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0083, Final Score: 0.5479
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 40/267 - Test Acc: 0.1131, MIA Forgetting Score: 0.0250, Final Score: 0.5315
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 41/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0400, Final Score: 0.5162
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 42/267 - Test Acc: 0.1572, MIA Forgetting Score: 0.0433, Final Score: 0.5353
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 43/267 - Test Acc: 0.2385, MIA Forgetting Score: 0.0267, Final Score: 0.5926
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 44/267 - Test Acc: 0.2385, MIA Forgetting Score: 0.0500, Final Score: 0.5692
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 45/267 - Test Acc: 0.2385, MIA Forgetting Score: 0.0133, Final Score: 0.6059
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 46/267 - Test Acc: 0.2385, MIA Forgetting Score: 0.0550, Final Score: 0.5642
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 48/267 - Test Acc: 0.2385, MIA Forgetting Score: 0.0600, Final Score: 0.5592
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 49/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0333, Final Score: 0.5229
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 50/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0300, Final Score: 0.5262
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 51/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0033, Final Score: 0.5529
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 52/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0733, Final Score: 0.4829
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 53/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0333, Final Score: 0.5229
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 54/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0867, Final Score: 0.4695
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 55/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0917, Final Score: 0.4645
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 56/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0483, Final Score: 0.5079
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 57/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0550, Final Score: 0.5012
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 58/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0317, Final Score: 0.5245
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 59/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0267, Final Score: 0.5295
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 60/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0383, Final Score: 0.5179
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 61/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0033, Final Score: 0.5529
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 62/267 - Test Acc: 0.1741, MIA Forgetting Score: 0.0433, Final Score: 0.5437
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 63/267 - Test Acc: 0.1754, MIA Forgetting Score: 0.0317, Final Score: 0.5561
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 64/267 - Test Acc: 0.1754, MIA Forgetting Score: 0.0517, Final Score: 0.5361
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 65/267 - Test Acc: 0.1754, MIA Forgetting Score: 0.0850, Final Score: 0.5027
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 66/267 - Test Acc: 0.1754, MIA Forgetting Score: 0.1483, Final Score: 0.4394
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 67/267 - Test Acc: 0.2385, MIA Forgetting Score: 0.1217, Final Score: 0.4976
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 68/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.0800, Final Score: 0.5418
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 69/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.0450, Final Score: 0.5768
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 70/267 - Test Acc: 0.1287, MIA Forgetting Score: 0.1017, Final Score: 0.4627
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 71/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0467, Final Score: 0.5095
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 72/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0317, Final Score: 0.5245
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 73/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0367, Final Score: 0.5195
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 74/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0233, Final Score: 0.5329
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 75/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0133, Final Score: 0.5429
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 76/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0733, Final Score: 0.4829
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 77/267 - Test Acc: 0.1248, MIA Forgetting Score: 0.0217, Final Score: 0.5407
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 78/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.0367, Final Score: 0.5852
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 79/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.0183, Final Score: 0.6035
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 80/267 - Test Acc: 0.1598, MIA Forgetting Score: 0.0233, Final Score: 0.5566
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 81/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0183, Final Score: 0.5379
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 82/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.1100, Final Score: 0.4462
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 83/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0533, Final Score: 0.5029
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 84/267 - Test Acc: 0.1131, MIA Forgetting Score: 0.0533, Final Score: 0.5032
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 85/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.0367, Final Score: 0.5852
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 86/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.0717, Final Score: 0.5502
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 87/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.1500, Final Score: 0.4718
# Batch 88/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.0650, Final Score: 0.5568
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 89/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.0900, Final Score: 0.5318
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 90/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.0900, Final Score: 0.5318
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 91/267 - Test Acc: 0.2385, MIA Forgetting Score: 0.1283, Final Score: 0.4909
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 92/267 - Test Acc: 0.2385, MIA Forgetting Score: 0.0700, Final Score: 0.5492
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 93/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0417, Final Score: 0.5145
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 95/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0117, Final Score: 0.5445
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 96/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0150, Final Score: 0.5412
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 97/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0450, Final Score: 0.5112
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 98/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0033, Final Score: 0.5529
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 99/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0233, Final Score: 0.5329
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 100/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0250, Final Score: 0.5312
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 101/267 - Test Acc: 0.1163, MIA Forgetting Score: 0.0933, Final Score: 0.4648
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 102/267 - Test Acc: 0.1754, MIA Forgetting Score: 0.0950, Final Score: 0.4927
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 103/267 - Test Acc: 0.1741, MIA Forgetting Score: 0.0983, Final Score: 0.4887
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 104/267 - Test Acc: 0.1754, MIA Forgetting Score: 0.1117, Final Score: 0.4761
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 105/267 - Test Acc: 0.2326, MIA Forgetting Score: 0.1367, Final Score: 0.4796
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 106/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.0667, Final Score: 0.5552
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 107/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.1550, Final Score: 0.4668
# Batch 108/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.0783, Final Score: 0.5435
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 109/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.0900, Final Score: 0.5318
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 110/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.1283, Final Score: 0.4935
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 111/267 - Test Acc: 0.2346, MIA Forgetting Score: 0.1100, Final Score: 0.5073
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 112/267 - Test Acc: 0.2157, MIA Forgetting Score: 0.1183, Final Score: 0.4895
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 113/267 - Test Acc: 0.2053, MIA Forgetting Score: 0.1217, Final Score: 0.4810
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 114/267 - Test Acc: 0.2320, MIA Forgetting Score: 0.1017, Final Score: 0.5143
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 115/267 - Test Acc: 0.2216, MIA Forgetting Score: 0.0983, Final Score: 0.5125
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 116/267 - Test Acc: 0.1793, MIA Forgetting Score: 0.1283, Final Score: 0.4613
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 117/267 - Test Acc: 0.1748, MIA Forgetting Score: 0.0767, Final Score: 0.5107
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 118/267 - Test Acc: 0.1741, MIA Forgetting Score: 0.0467, Final Score: 0.5404
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 119/267 - Test Acc: 0.1741, MIA Forgetting Score: 0.0633, Final Score: 0.5237
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 120/267 - Test Acc: 0.1144, MIA Forgetting Score: 0.0183, Final Score: 0.5388
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 121/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0717, Final Score: 0.4845
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 122/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0133, Final Score: 0.5429
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 123/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0400, Final Score: 0.5162
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 124/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0733, Final Score: 0.4829
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 125/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0500, Final Score: 0.5062
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 126/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0517, Final Score: 0.5045
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 127/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0050, Final Score: 0.5512
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 128/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0383, Final Score: 0.5179
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 129/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0600, Final Score: 0.4962
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 130/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0767, Final Score: 0.4795
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 131/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0267, Final Score: 0.5295
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 132/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0350, Final Score: 0.5212
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 133/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0683, Final Score: 0.4879
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 134/267 - Test Acc: 0.1124, MIA Forgetting Score: 0.0633, Final Score: 0.4929
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 135/267 - Test Acc: 0.2391, MIA Forgetting Score: 0.0717, Final Score: 0.5479
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 136/267 - Test Acc: 0.2391, MIA Forgetting Score: 0.0733, Final Score: 0.5462
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 137/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.0450, Final Score: 0.5768
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 138/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.0600, Final Score: 0.5618
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 139/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.0517, Final Score: 0.5702
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 140/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.1767, Final Score: 0.4452
# Batch 142/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.1067, Final Score: 0.5152
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 143/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.1250, Final Score: 0.4968
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 144/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.0917, Final Score: 0.5302
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 145/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.0867, Final Score: 0.5352
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 146/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.1217, Final Score: 0.5002
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 147/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.0667, Final Score: 0.5552
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 148/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.0933, Final Score: 0.5285
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 149/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.0800, Final Score: 0.5418
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 150/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.1017, Final Score: 0.5202
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 151/267 - Test Acc: 0.2437, MIA Forgetting Score: 0.0933, Final Score: 0.5285
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 152/267 - Test Acc: 0.2144, MIA Forgetting Score: 0.0817, Final Score: 0.5255
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 153/267 - Test Acc: 0.1754, MIA Forgetting Score: 0.1117, Final Score: 0.4761
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 154/267 - Test Acc: 0.1754, MIA Forgetting Score: 0.1083, Final Score: 0.4794
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 155/267 - Test Acc: 0.1754, MIA Forgetting Score: 0.0867, Final Score: 0.5011
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 156/267 - Test Acc: 0.1754, MIA Forgetting Score: 0.1267, Final Score: 0.4611
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 157/267 - Test Acc: 0.1754, MIA Forgetting Score: 0.1233, Final Score: 0.4644
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 158/267 - Test Acc: 0.1754, MIA Forgetting Score: 0.0867, Final Score: 0.5011
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 159/267 - Test Acc: 0.1754, MIA Forgetting Score: 0.1067, Final Score: 0.4811
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 160/267 - Test Acc: 0.1754, MIA Forgetting Score: 0.1067, Final Score: 0.4811
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 161/267 - Test Acc: 0.1754, MIA Forgetting Score: 0.1350, Final Score: 0.4527
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 162/267 - Test Acc: 0.1754, MIA Forgetting Score: 0.0817, Final Score: 0.5061
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 163/267 - Test Acc: 0.1754, MIA Forgetting Score: 0.1233, Final Score: 0.4644
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 164/267 - Test Acc: 0.1741, MIA Forgetting Score: 0.1233, Final Score: 0.4637
# Forgetting score below threshold. Fine-tuning with only classification loss.
# Batch 165/267 - Test Acc: 0.1761, MIA Forgetting Score: 0.1167, Final Score: 0.4714
# Forgetting score below threshold. Fine-tuning with only classification loss.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 22
#      19 max_forgetting_score = 0.09  # Forgetting score saving threshold
#      20 val_sample = 300 # Number of samples to use for the monitoring process
# ---> 22 train_dlfd(
#      23         dlfm_model, data_loaders, criterion, optimizer, device,
#      24         perturbation_steps, perturbation_strength, forget_threshold, max_forgetting_score,
#      25         initial_retain_weight, final_retain_weight, forget_weight, val_sample, path
#      26     )
#
# File ~/DLFD/unlearn/dlfd.py:135, in train_dlfd(dlfm_model, data_loaders, criterion, optimizer, device, perturbation_steps, perturbation_strength, forget_threshold, max_forgetting_score, initial_retain_weight, final_retain_weight, forget_weight, val_sample, path)
#     132     optimizer.step()
#     134 test_acc = calculate_accuracy(dlfm_model, data_loaders['val'], criterion, device)
# --> 135 mia = MIA_training_monitor(dlfm_model, data_loaders["retain_test"],
#     136                        data_loaders['forget_test'], data_loaders['val'], device, max_samples=val_sample)
#     137 forgetting_score = mia["Forgetting Score"]
#     138 final_score = (test_acc["Acc"] + 1 - mia["Forgetting Score"] * 2) / 2
#
# File ~/DLFD/evaluation/mia.py:110, in MIA_training_monitor(model, retain_loader, forget_loader, test_loader, device, max_samples)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/DLFD/evaluation/mia.py:64, in compute_losses_fast(model, loader, device, max_samples)
#      61 start_idx = 0
#      63 stream = torch.cuda.Stream()
# ---> 64 with torch.cuda.stream(stream):
#      65     with torch.no_grad(), torch.cuda.amp.autocast():
#      66         for inputs, labels in sampled_loader:
#
# File ~/.conda/envs/dlfd/lib/python3.12/site-packages/torch/utils/data/dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/.conda/envs/dlfd/lib/python3.12/site-packages/torch/utils/data/dataloader.py:673, in _SingleProcessDataLoaderIter._next_data(self)
#     671 def _next_data(self):
#     672     index = self._next_index()  # may raise StopIteration
# --> 673     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     674     if self._pin_memory:
#     675         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/.conda/envs/dlfd/lib/python3.12/site-packages/torch/utils/data/_utils/fetch.py:50, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      48 if self.auto_collation:
#      49     if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:
# ---> 50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
#      52         data = [self.dataset[idx] for idx in possibly_batched_index]
#
# File ~/.conda/envs/dlfd/lib/python3.12/site-packages/torch/utils/data/dataset.py:420, in Subset.__getitems__(self, indices)
#     418     return self.dataset.__getitems__([self.indices[idx] for idx in indices])  # type: ignore[attr-defined]
#     419 else:
# --> 420     return [self.dataset[self.indices[idx]] for idx in indices]
#
# File ~/DLFD/MUFAC_loader.py:38, in CustomDataset.__getitem__(self, idx)
#      36 image_path, age_class = self.image_age_list[idx]
#      37 full_path = os.path.join(self.image_directory, image_path)
# ---> 38 img = Image.open(full_path).convert('RGB')  # Ensure the image is in RGB format
#      39 label = self.age_class_to_label[age_class]
#      41 if self.transform:
#
# File ~/.conda/envs/dlfd/lib/python3.12/site-packages/PIL/Image.py:995, in Image.convert(self, mode, matrix, dither, palette, colors)
#     992 if mode in ("BGR;15", "BGR;16", "BGR;24"):
#     993     deprecate(mode, 12)
# --> 995 self.load()
#     997 has_transparency = "transparency" in self.info
#     998 if not mode and self.mode == "P":
#     999     # determine default mode
#
# File ~/.conda/envs/dlfd/lib/python3.12/site-packages/PIL/ImageFile.py:293, in ImageFile.load(self)
#     290         raise OSError(msg)
#     292 b = b + s
# --> 293 n, err_code = decoder.decode(b)
#     294 if n < 0:
#     295     break
#
# KeyboardInterrupt:

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_path = 'checkpoint/age_dlfd.pth'
dlfm_model = load_model(8, device, model_path)

test_acc = calculate_accuracy(dlfm_model, data_loaders['test'], criterion, device)z
mia = MIA(dlfm_model, data_loaders["retain_test"], data_loaders['forget_test'], data_loaders['test'], device)
final_score = (test_acc["Acc"] + 1 - abs(mia["Forgetting Score"] * 2)) / 2
print(f'Test Acc: {test_acc}')
print(f'MIA :{mia}')
print(f'Final score: {final_score}')
# Out:
# Test Acc: {'Loss': 0.03269348626441144, 'Acc': 0.6196808510638298, 'Top-2 Acc': 0.8736702127659575}
# MIA :{'MIA Regression Accuracy': 0.7411744296990198, 'MIA CV Accuracy': 0.527906976744186, 'Forgetting Score': 0.027906976744185963}
# Final score: 0.781933448787729
